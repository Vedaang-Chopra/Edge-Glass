# %%
! uv pip install --extra-index-url https://download.pytorch.org/whl/cu121 torch torchvision torchaudio
# Out:
# Using Python 3.12.5 environment at: /storage/ice1/1/0/vchopra37/projects/edge_glass/edge_glass_env
# Audited 3 packages in 873ms

# %%
# Core libs
! uv pip install transformers accelerate sentence-transformers \
            pillow soundfile librosa pyyaml tqdm matplotlib \
            ipykernel pytest
# Out:
# Using Python 3.12.5 environment at: /storage/ice1/1/0/vchopra37/projects/edge_glass/edge_glass_env
# Resolved 96 packages in 2.12s
# Prepared 3 packages in 261ms
# Installed 4 packages in 111ms=5.1.2
#  + iniconfig==2.3.0
#  + pluggy==1.6.0
#  + pytest==8.4.2
#  + sentence-transformers==5.1.2

# %%
# (Optional) quality-of-life
!  uv pip install ruff black isort
# Out:
# Using Python 3.12.5 environment at: /storage/ice1/1/0/vchopra37/projects/edge_glass/edge_glass_env
# Resolved 9 packages in 212ms
# Prepared 6 packages in 344ms
# Installed 7 packages in 53ms
#  + black==25.9.0
#  + click==8.3.0
#  + isort==7.0.0
#  + mypy-extensions==1.1.0
#  + pathspec==0.12.1
#  + pytokens==0.3.0
#  + ruff==0.14.3
