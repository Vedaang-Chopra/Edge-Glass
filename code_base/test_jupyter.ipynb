# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
import torch, torchaudio, torchvision, transformers
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Device count:", torch.cuda.device_count())
    print("GPU name:", torch.cuda.get_device_name(0))
print("torch:", torch.__version__)
print("transformers:", transformers.__version__)
# Out:
# /storage/ice1/1/0/vchopra37/projects/edge_glass/edge_glass_env/lib/python3.12/site-packages/transformers/utils/hub.py:110: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# CUDA available: True
# Device count: 1
# GPU name: NVIDIA H200
# torch: 2.9.0+cu128
# transformers: 4.57.1

# %%
from utils.config import load_config, select_device, select_dtype
cfg = load_config("configs/base.yaml")
print(cfg)
print("device:", select_device(cfg))
print("dtype:", select_dtype(cfg))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from utils.config import load_config, select_device, select_dtype
#       2 cfg = load_config("configs/base.yaml")
#       3 print(cfg)
#
# ModuleNotFoundError: No module named 'utils'
